# %%
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
#parameters
k = [1,2,3,4,9,7.5,5]
theta = [2,2,2,2,1,0.5,1]
params = np.array((np.array(k),np.array(theta)))
params = np.transpose(params)

# %%
def gamma_dist(shape,scale,n):
    s = np.random.gamma(shape, scale, n)
    print("The mean of the draw when k =", shape, "and theta =", scale , "is", np.mean(s))
    print("The standard deviation of the draw when k =", shape, "and theta =", scale , "is", np.std(s))
    sns.distplot(s, hist=False, label = params[i])

# %%
for i in range(len(k)):
    gamma_dist(k[i],theta[i],1000)
# Out:
# The mean of the draw when k = 1 and theta = 2 is 1.99528308603
# The standard deviation of the draw when k = 1 and theta = 2 is 1.99158621339
# The mean of the draw when k = 2 and theta = 2 is 3.99334033053
# The standard deviation of the draw when k = 2 and theta = 2 is 2.68711067526
# The mean of the draw when k = 3 and theta = 2 is 5.98826840282
# The standard deviation of the draw when k = 3 and theta = 2 is 3.56424427161
# The mean of the draw when k = 4 and theta = 2 is 7.99899022308
# The standard deviation of the draw when k = 4 and theta = 2 is 3.88606919519
# The mean of the draw when k = 9 and theta = 1 is 9.00883143529
# The standard deviation of the draw when k = 9 and theta = 1 is 3.06408297635
# The mean of the draw when k = 7.5 and theta = 0.5 is 3.76304190769
# The standard deviation of the draw when k = 7.5 and theta = 0.5 is 1.40647948608
# The mean of the draw when k = 5 and theta = 1 is 5.12027957733
# ...
