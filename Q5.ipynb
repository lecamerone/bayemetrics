# %%
from scipy.stats import t
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set_context('notebook') # optimise figures for notebook display
sns.set_style('ticks') # set default plot style
colours = ['#1F77B4', '#FF7F0E', '#2CA02C', '#DB2728', '#9467BD', '#8C564B', '#E377C2','#7F7F7F', '#BCBD22', '#17BECF']
crayon = ['#4E79A7','#F28E2C','#E15759','#76B7B2','#59A14F', '#EDC949','#AF7AA1','#FF9DA7','#9C755F','#BAB0AB']
sns.set_palette(colours) # set custom color scheme
# %matplotlib inline
plt.rcParams['figure.figsize'] = (9, 6)

# %%
def t_dist(df,n):
    r = t.rvs(df, loc=1.5, scale=2, size = n)
    print("The mean of the draws with", df, "degrees of freedom is ", np.mean(r))
    print("The standard deviation of the draws with", df, "degrees of freedom is ", np.std(r))
    sns.distplot(r, hist=False)

# %%
DF = [3,5,10,20,30,60]
for i in range(len(DF)):
    t_dist(DF[i], 1000)
# Out:
# The mean of the draws with 3 degrees of freedom is  1.54618250913
# The standard deviation of the draws with 3 degrees of freedom is  3.2632645202
# The mean of the draws with 5 degrees of freedom is  1.53471379387
# The standard deviation of the draws with 5 degrees of freedom is  2.46442645196
# The mean of the draws with 10 degrees of freedom is  1.54710130936
# The standard deviation of the draws with 10 degrees of freedom is  2.27469570109
# The mean of the draws with 20 degrees of freedom is  1.50615572651
# The standard deviation of the draws with 20 degrees of freedom is  2.14174863932
# The mean of the draws with 30 degrees of freedom is  1.62701352368
# The standard deviation of the draws with 30 degrees of freedom is  2.06431254378
# The mean of the draws with 60 degrees of freedom is  1.43822713809
# The standard deviation of the draws with 60 degrees of freedom is  2.06161780302

# %%
t_dist(DF[1], 1000)
# Out:
# The mean of the draws with 5 degrees of freedom is  1.55671296719
# The standard deviation of the draws with 5 degrees of freedom is  2.62145403141

# %%
t_dist(DF[2], 1000)
# Out:
# The mean of the draws with 10 degrees of freedom is  1.48849491275
# The standard deviation of the draws with 10 degrees of freedom is  2.19253436319

# %%
t_dist(DF[3], 1000)
# Out:
# The mean of the draws with 20 degrees of freedom is  1.50095046055
# The standard deviation of the draws with 20 degrees of freedom is  2.06600128271

# %%
t_dist(DF[4], 1000)
# Out:
# The mean of the draws with 30 degrees of freedom is  1.49511338141
# The standard deviation of the draws with 30 degrees of freedom is  2.06351070255

# %%
t_dist(DF[5], 1000)
# Out:
# The mean of the draws with 60 degrees of freedom is  1.4860359895
# The standard deviation of the draws with 60 degrees of freedom is  2.13291807833
