# %%
from scipy.stats import chi2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_context('notebook') # optimise figures for notebook display
sns.set_style('ticks') # set default plot style
colours = ['#1F77B4', '#FF7F0E', '#2CA02C', '#DB2728', '#9467BD', '#8C564B', '#E377C2','#7F7F7F', '#BCBD22', '#17BECF']
crayon = ['#4E79A7','#F28E2C','#E15759','#76B7B2','#59A14F', '#EDC949','#AF7AA1','#FF9DA7','#9C755F','#BAB0AB']
sns.set_palette(colours) # set custom color scheme
# %matplotlib inline
plt.rcParams['figure.figsize'] = (9, 6)

# %%
def chi_sq(df, n):
    r = chi2.rvs(df, size=n)
    print("The mean of the sample with ", n, "draws is ", np.mean(r))
    print("The standard deviation of the sample with ", n, "draws is ", np.std(r))
    sns.distplot(r, hist=False, label = df)

# %%
DF = [3,5,10,20,30,60]
for i in range(len(DF)):
    chi_sq(DF[i],1000)
# Out:
# The mean of the sample with  1000 draws is  2.97229506497
# The standard deviation of the sample with  1000 draws is  2.36382613054
# The mean of the sample with  1000 draws is  5.10991379443
# The standard deviation of the sample with  1000 draws is  3.1916819033
# The mean of the sample with  1000 draws is  9.89392182224
# The standard deviation of the sample with  1000 draws is  4.35050128622
# The mean of the sample with  1000 draws is  20.3744077451
# The standard deviation of the sample with  1000 draws is  6.53412759855
# The mean of the sample with  1000 draws is  29.7038764264
# The standard deviation of the sample with  1000 draws is  7.72179073751
# The mean of the sample with  1000 draws is  59.8503480651
# The standard deviation of the sample with  1000 draws is  10.6501634095
